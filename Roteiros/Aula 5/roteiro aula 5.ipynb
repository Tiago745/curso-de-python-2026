# %% [markdown]
# 1. PiP
# 2. Numpy
# 3. métodos e atributos
# 4. Pandas
# 5. DataFrame
# 6. Series
# 7. carregar dados do excel, csv...
# 8. métodos e atributos de resumo(head,  tail,  describe,  shape,  dtypes,info...)
# 9. métodos de fatiamento(loc, iloc, iat, at, T...)
# 10. métodos gráficos(hist, plot, scatter)

# %% [markdown]
# história da aula, esqueleto:
# - Introdução ao ambiente de desenvolvimento (PiP)
#     - falar rapidamente sobre os motivos de criarmos um venv e como prosseguir caso de errado no seu pc
# - Instalação e configuração do Numpy e Pandas
#     - caso o anterior deu certo, esse certamente dará, pois venv sempre vem com pip
# - Numpy
#     - ...
# - Apresentação do banco de dados a ser utilizado (Pandas)
#     - O banco de dados será as populações do Brasil
#         - Carregamento dos dados utilizando Pandas
#     - checamos os typos
#         - corrigimos caso seja object
#     - Exploração inicial dos dados com métodos e atributos de resumo
#         - veremos o começo (head)
#         - deduzimos a organização inical do df
#     - explica-se a diferença entre head, describe, shape, dtypes, info
#     - Manipulação e fatiamento dos dados com loc, iloc, iat, at
#         - localizamos a população de uma cidade de duas formas diferentes
#         - filtraremos as cidades com mais 100 mil habitantes
#         - achamos as cidades que cresceram mais de 3%
#     - criar uma nova coluna com a população do ano anterior
#     - Visualização dos dados com métodos gráficos (hist, plot, scatter)
#         - qual a cidade que mais cresceu?
#         - qual a cidade mais populosa?
#         - qual a relação entre população e cescimento?
# - Exercícios práticos para fixação dos conceitos abordados
#     - como você dividiria a tabela por estado?
#         - Extra: Qual é o estado mais populoso?
#     - Localize a cidade X e compare com a população de São Paulo capital, quantas X cabem em SP?
#     - Após dividir o df por estados, como você limparia a coluna dos municipios
