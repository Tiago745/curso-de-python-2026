# %% [markdown]
# ## [Foto banner curso dev 2026]

# %% [markdown]
# # **[Título Temático com Emojis]**

# %% [markdown]
# ## **Lista de Exercício [Número] - [Tema]**
# ### Fala devs, blz?
#
# Essa é a nossa [número]ª lista de exercícios, parabéns por ter chegado até aqui! 🚀
#
# Dessa vez, iremos fixar os conceitos aprendidos em [aula/tema]! Os exercícios a seguir abordam [lista de tópicos]. Bora lá?
#
# ### O que você vai fazer: [emoji]
# - [tópicos dos exercicios]
#
# **Dúvidas? Só mandar no [link] que está rodando no canal do WhatsApp! Bora codar! 🚀**
#
#
# Abraços,
# **Equipe FEA.dev**
#
# <br>

# %% [markdown]
# ## 🚀 Exercício 1: [Título do Exercício]

# %% [markdown]
# ### O que você vai fazer:
# [Descrição detalhada do exercício com passos claros e dicas de implementação]

# %% [markdown]
# ## [emoji] Exercício 2: [Título do Exercício]

# %% [markdown]
# ### O que você vai fazer:
# [Descrição detalhada do exercício com passos claros e dicas de implementação]

# %% [markdown]
# ## [emoji] Exercício 3: [Título do Exercício]

# %% [markdown]
# ### O que você vai fazer:
# [Descrição detalhada do exercício com passos claros e dicas de implementação]

# %% [markdown]
# ## [emoji] Exercício 4: [Título do Exercício]

# %% [markdown]
# ### O que você vai fazer:
# [Descrição detalhada do exercício com passos claros e dicas de implementação]

# %% [markdown]
# # **Desafio: 🔒 [Título do Desafio]**

# %% [markdown]
# [Descrição completa do desafio com contexto e exemplos. Detalhe os passos que devem ser seguidos e os requisitos da solução.]
